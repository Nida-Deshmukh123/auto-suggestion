# %%
import pandas as pd
import numpy as np
import textdistance
import re
from collections import Counter

# %% [markdown]
# # File Opening And Cleaning (change formate to utf-8)

# %%
word = []

with open('autocorrect book.txt', 'r', encoding='utf-8') as f:
    data = f.read()
    data = data.lower()
    words = re.findall('\w+', data)
    words += words

print(words[0:10])
# Out:
# ['the', 'project', 'gutenberg', 'ebook', 'of', 'moby', 'dick', 'or', 'the', 'whale']

# %% [markdown]
# # make vocabulary

# %%
len(words)
# Out:
# 445710

# %%
V = set(words)
V
# Out:
# {'empty',
#  'favourable',
#  'glimmering',
#  'hooped',
#  'oozy',
#  'apron',
#  'thistle',
#  'ungraspable',
#  'contortions',
#  'greyhounds',
#  'bumped',
#  'pinny',
#  'whipped',
#  'solve',
#  'hav',
#  'bruised',
#  'gore',
#  'sustain',
#  'distrusted',
#  'fawned',
#  'noiseless',
#  'owners',
#  'turtles',
#  'harbors',
#  'commonest',
#  'counter',
#  'scrimps',
#  'resign',
#  'exhausting',
#  'practical',
#  'aroma',
#  'amounts',
#  'imperial',
#  'tying',
#  'matted',
#  'tanned',
#  'owned',
#  'error',
#  'banks',
#  'relaxed',
#  'foggy',
#  'garters',
#  'wrapper',
#  'mightest',
#  'hurl',
#  'angularly',
#  'speedy',
#  'chewed',
#  'secondly',
#  'yawning',
#  'lancet',
#  'date',
#  'pouring',
#  'mimicking',
#  'circumpolar',
#  'indebted',
#  'broiling',
#  'success',
#  'ween',
#  'glen',
#  'shading',
#  'unheeded',
#  'defined',
#  'entreated',
#  'entered',
#  '47',
#  'anew',
#  '_that',
#  'geometry',
#  'et',
#  'eloquent',
#  'fang',
#  'hemlock',
#  'gnaw',
#  'rakes',
#  'bargain',
#  'legatees',
#  'gripping',
#  'tempestuous',
#  'sociably',
#  'convenient',
#  'rich',
#  'wery',
#  'idleness',
#  'monks',
#  'aldermen',
#  'rear',
#  'stingy',
#  'less',
#  'outlet',
#  'lived',
#  'gates',
#  'tarred',
#  'results',
#  'trowsers',
#  'unnearable',
#  'bolts',
#  'cisterns',
#  'pert',
#  'joyously',
#  'inferable',
#  'settlers',
#  'candid',
#  'marge',
#  'superstitiously',
#  'whereupon',
#  'pilgrim',
#  '83',
#  'reporting',
#  'chains',
#  'bladders',
#  'trap',
#  'zogranda',
#  'engendered',
#  'wrapall',
#  'stranger',
#  'likely',
#  'crumb',
#  'astronomy',
#  'drawbacks',
#  'irresolute',
#  'hones',
#  'braver',
#  'far',
#  'neutral',
#  'hasty',
#  'pottsfich',
#  'various',
#  'smiting',
#  'insulting',
#  'residuary',
#  'carnation',
#  'lend',
#  'unsubstantial',
#  'transpired',
#  'hawser',
#  'euroclydon',
#  'wear',
#  'rumbles',
#  'sereneness',
#  'absorbingly',
#  'mobbing',
#  'moons',
#  'sported',
#  'lift',
#  'repressed',
#  'speechlessly',
#  'crockery',
#  'swimmer',
#  'recognise',
#  'allured',
#  'requiring',
#  'spontaneous',
#  'soonest',
#  '1778',
#  'wilt',
#  'mount',
#  'compounded',
#  'bipeds',
#  'ordinary',
#  'guard',
#  'catched',
#  '_dancing_',
#  'fagged',
#  'drowns',
#  'marshals',
#  'rumors',
#  'laid',
#  'roundabout',
#  'woman',
#  'honor',
#  'nipper',
#  'comforters',
#  'hist_',
#  'palest',
#  'pier',
#  'extinguished',
#  'gulp',
#  'barges',
#  'unmisgiving',
#  'who',
#  'bones',
#  'horizon',
#  'master',
#  'picture',
#  'churches',
#  'widely',
#  'laborers',
#  'synod',
#  'prevail',
#  'screwing',
#  'authorities',
#  'reserved',
#  'groupings',
#  'occupant',
#  'chap',
#  'stress',
#  'forlorn',
#  'knaves',
#  'vividly',
#  'yankees',
#  'verdant',
#  'apply',
#  'enlisting',
#  'ungracious',
#  'sieve',
#  'moored',
#  'punish',
#  'mephistophelean',
#  'reserving',
#  'total',
#  'alien',
#  'diffused',
#  'bring',
#  'yourselves',
#  'bankers',
#  'eely',
#  'wondered',
#  'contented',
#  'hedgehog',
#  'termination',
#  'yoked',
#  'reeling',
#  'convolutions',
#  'jesty',
#  'instantly',
#  'bulls',
#  'purchas_',
#  'asserted',
#  'whiffs',
#  'kentucky',
#  'appearance',
#  'impressions',
#  'brazil',
#  'donations',
#  'domes',
#  'accident',
#  'dry',
#  'seductive',
#  'nursing',
#  'shiverings',
#  'costs',
#  'foundering',
#  'quality',
#  'connect',
#  '53',
#  'senior',
#  'lighten',
#  'rushes',
#  'pours',
#  'abstained',
#  'riotous',
#  'willis',
#  'o',
#  'tisbury',
#  'serve',
#  'manœuvres',
#  'arion',
#  'musked',
#  'ceremonies',
#  'mastodon',
#  'mannerly',
#  'execute',
#  'ascending',
#  'beak',
#  'continual',
#  'pantheists',
#  'creaking',
#  'pangs',
#  'paid',
#  'swinging',
#  'danish',
#  'gay',
#  'rejoice',
#  'sinecure',
#  'originator',
#  'rightly',
#  'phrenological',
#  'dante',
#  'soils',
#  'destroying',
#  'murderous',
#  'troil',
#  'voluntary',
#  'napkins',
#  'coasts',
#  'adroit',
#  'tit',
#  'g',
#  'clingings',
#  'loungingly',
#  'tide',
#  'garrison',
#  'risings',
#  'faced',
#  'revengeful',
#  'what',
#  'foolishly',
#  '100',
#  'vengeance',
#  'hug',
#  'epitome',
#  'flour',
#  'glanced',
#  'wisdom',
#  'marten',
#  'vials',
#  'remorseless',
#  'whetstones',
#  'unsounded',
#  'tut',
#  'proffer',
#  'kiss',
#  'tosses',
#  'unfortunate',
#  'bearskin',
#  '400',
#  'memorial',
#  'harlot',
#  'seemly',
#  'serpents',
#  'creeping',
#  'revive',
#  'craven',
#  'fuddled',
#  'furred',
#  'wells',
#  'altered',
#  'word',
#  'handled',
#  'pursued',
#  'circling',
#  'sixth',
#  'arterial',
#  'conquering',
#  'joppa',
#  'strangeness',
#  'mab',
#  '144',
#  'achieved',
#  'surest',
#  'powerless',
#  'tertiary',
#  'glim',
#  'scuttling',
#  'loved',
#  'hearkening',
#  'enlarges',
#  'brushwood',
#  'gospel',
#  'unmixed',
#  'perquisites',
#  'confounding',
#  'waked',
#  'limited',
#  'silently',
#  'weakling',
#  'spotted',
#  'defile',
#  'crop',
#  'tyros',
#  'concocted',
#  'weeps',
#  'steers',
#  'manned',
#  'veriest',
#  'unsmoothable',
#  'confidential',
#  'log',
#  'doubloon',
#  'roll',
#  'slept',
#  'frightens',
#  'flourished',
#  'shunned',
#  'scramble',
#  'denderah',
#  'wharves',
#  'fears',
#  'abiding',
#  'scoresby',
#  'makest',
#  'sin',
#  'understood',
#  'carpets',
#  'curves',
#  'flatly',
#  'ideas',
#  '_nostril',
#  'rim',
#  'deceive',
#  'colnett',
#  'limitations',
#  'eluded',
#  'endeavor',
#  'calmness',
#  'panics',
#  'indiscreet',
#  'issuing',
#  'counsel',
#  'luxuriant',
#  'backing',
#  'claps',
#  'courage',
#  'noise',
#  'plight',
#  'completing',
#  'fallen',
#  'lard',
#  'shaft',
#  'blocksburg',
#  'concept',
#  'netherlands',
#  'amlodipine',
#  'effulgent',
#  'fin',
#  'bench',
#  'brahmins',
#  'gallery',
#  'poorest',
#  'outright',
#  'notions',
#  'waxes',
#  'discriminating',
#  '_pequod_',
#  'eaten',
#  'individually',
#  'rechurned',
#  'nun',
#  'mocked',
#  'newspaper',
#  'seated',
#  'giving',
#  'hopeless',
#  'puffed',
#  'uncivilized',
#  'detach',
#  'vaults',
#  'lurid',
#  'destructive',
#  'february',
#  'floes',
#  'tuns',
#  'cordage',
#  'crappo',
#  'pained',
#  'officers',
#  'religionists',
#  'steal',
#  'limitation',
#  'lees',
#  'sundering',
#  'walnut',
#  'depending',
#  'latitudes',
#  'shad',
#  'lighthouse',
#  'entrails',
#  'chapel',
#  'remote',
#  'providing',
#  'depended',
#  'reader',
#  'shavings',
#  'concern',
#  'spoke',
#  'asked',
#  'etherial',
#  'genera',
#  'youthful',
#  'draws',
#  'pennant',
#  'discovery',
#  'unilluminated',
#  'wonderful',
#  'leading',
#  'listening',
#  'tarried',
#  'dish',
#  'preferred',
#  'resolutely',
#  'dance',
#  'bowling',
#  'uttons',
#  'allusions',
#  'saucers',
#  'quickly',
#  'inattention',
#  'collared',
#  'defect',
#  'fish',
#  'hogarthian',
#  'unsolicited',
#  'tattered',
#  'calves',
#  'strange',
#  'duskier',
#  'enemies',
#  'clamorous',
#  'pippin',
#  'precipice',
#  'effects',
#  'relapses',
#  'fadest',
#  'rafters',
#  'crafty',
#  'tear',
#  'uncanonical',
#  'hangman',
#  'swept',
#  'confidentially',
#  'added',
#  'beckoning',
#  'argosy',
#  'newlanded',
#  'sinker',
#  '_sudden',
#  'turk',
#  'defence',
#  'card',
#  'briefly',
#  'squares',
#  'rigger',
#  'reviewed',
#  'forerunning',
#  'unshored',
#  'conflicting',
#  'inaccurate',
#  'liberal',
#  'lovers',
#  'grindstone',
#  'brew',
#  'disgorge',
#  'admeasurements',
#  'brief',
#  'neglected',
#  'seasoning',
#  'colder',
#  'ingin',
#  'vainly',
#  'checks',
#  'gayhead',
#  'greenly',
#  'elevation',
#  'weakened',
#  'anguish',
#  'mongrel',
#  'flesh',
#  'fa',
#  'flapped',
#  'fairbanks',
#  'lost_',
#  'opine',
#  'dismasted',
#  'drunk',
#  '122',
#  'learned',
#  'butchers',
#  'toder',
#  'surface',
#  'lives',
#  'spires',
#  'agassiz',
#  'triumphs',
#  'spindles',
#  'philosophers',
#  'anointing',
#  'nothingness',
#  'reverenced',
#  'silks',
#  'rebut',
#  'belisarius',
#  'pagoda',
#  'shivering',
#  'siberia',
#  'bodied',
#  'cursing',
#  'ankles',
#  'articles',
#  'teneriffe',
#  'boughs',
#  'pore',
#  'comets',
#  'mouthfuls',
#  'sly',
#  'whistlingly',
#  'shaster',
#  'workman',
#  'expanding',
#  'featuring',
#  '1828',
#  'plains',
#  'growlingly',
#  'beaches',
#  'climb',
#  'sheaves',
#  'darted',
#  'persist',
#  'beats',
#  'expressed',
#  'detail',
#  'salamander',
#  'flickering',
#  'backwoods',
#  'witchery',
#  'cocks',
#  'terminating',
#  'forsaken',
#  'contrary',
#  'resulting',
#  'oily',
#  'amelia',
#  'apprised',
#  'dinner',
#  'tingled',
#  'farces',
#  'unwonted',
#  'bawl',
#  'library',
#  'encounters',
#  'flash',
#  'heidelburgh',
#  'cloistered',
#  'share',
#  'corroded',
#  'electricity',
#  'princess',
#  'shipyards',
#  'rescuing',
#  'tokens',
#  'loaded',
#  'impatiently',
#  'licensed',
#  'proprietary',
#  'allowances',
#  'hold',
#  'deficiencies',
#  'comprise',
#  'befallen',
#  'indignant',
#  'nondescripts',
#  'remonstrate',
#  'subjects',
#  'inveterate',
#  'threatens',
#  'label',
#  'material',
#  'winks',
#  'presents',
#  'calculate',
#  'tauntingly',
#  'hardicanutes',
#  'hangs',
#  'orthodoxy',
#  'announcing',
#  'shower',
#  'irresponsible',
#  'forbear',
#  'noways',
#  'intuitions',
#  'sharper',
#  'ass',
#  'em',
#  'inquiring',
#  'tenement',
#  'lege',
#  'preposterous',
#  'transcend',
#  'whiff',
#  'yellow',
#  'girls',
#  'strangest',
#  'embraced',
#  'doors',
#  'domestic',
#  'junction',
#  'halls',
#  'monied',
#  '126',
#  'corporeally',
#  'inshore',
#  'diaz',
#  'pack',
#  'perturbation',
#  'immortals',
#  'greedily',
#  'style',
#  'modes',
#  'unoutgrown',
#  'donned',
#  '98',
#  'cautious',
#  'dissertations',
#  'brigs',
#  'nathan',
#  'unholy',
#  'folds',
#  'cherish',
#  'superstition',
#  'maimed',
#  'platonian',
#  'facing',
#  'worshipping',
#  'yelled',
#  'befall',
#  'overrun',
#  'prate',
#  'captors',
#  'inkstand',
#  'tweezers',
#  'places',
#  'evilly',
#  'nice',
#  'impenitent',
#  'pedlar',
#  'circumstance',
#  'glutinous',
#  'starboard',
#  'depends',
#  'consideration',
#  'included',
#  'frontiers',
#  'tip',
#  'kingly',
#  'tubs',
#  'deaths',
#  'execrations',
#  '131',
#  'sinew',
#  'interpreter',
#  'many',
#  'its',
#  'clapping',
#  'argued',
#  'quarrelsome',
#  'learning',
#  'induce',
#  'unfathered',
#  'dollar',
#  'truthfully',
#  'ruthless',
#  '_missionary',
#  'chapels',
#  'play',
#  'pirouetting',
#  'expediency',
#  'frequency',
#  'woody',
#  'nate',
#  'elephants',
#  'chasm',
#  'skittishly',
#  'clothed',
#  'sinned',
#  'nosegay',
#  'hatch',
#  'collectedness',
#  'inordinate',
#  'affairs',
#  'compassion',
#  'looked',
#  'whichever',
#  'lily',
#  'within',
#  'clanking',
#  'interluding',
#  'thumbs',
#  'luridly',
#  'flutterings',
#  'conjoined',
#  'intensities',
#  'yawned',
#  'soothes',
#  'extending',
#  'theatre',
#  'inexperienced',
#  'man',
#  'twists',
#  'eddying',
#  'greenness',
#  'ignite',
#  'cavalier',
#  'characters',
#  'spear',
#  'depict',
#  'incommoding',
#  '3',
#  'pryed',
#  'dention',
#  'pick',
#  'lane',
#  'regulations',
#  'loftiest',
#  'unhinged',
#  'habitudes',
#  'task',
#  'lightest',
#  'emerged',
#  'sweating',
#  'clotting',
#  'verdes',
#  'steelkilt',
#  'bottle',
#  'phrensies',
#  'torso',
#  'latter',
#  'unexpectedly',
#  'obey',
#  'conversed',
#  '_tales',
#  'drawlingly',
#  'libra',
#  'blossom',
#  'personified',
#  'sportively',
#  'character',
#  'genteelly',
#  'throbbings',
#  '_lord',
#  'lean',
#  'desiring',
#  'lounging',
#  'grievances',
#  'act',
#  'lens',
#  'bottom',
#  'couple',
#  'degenerated',
#  'voted',
#  'rarmai',
#  'wheeling',
#  'generations',
#  'cruel',
#  'redistribution',
#  'meanwhile',
#  'jackets',
#  'hatched',
#  'fashion',
#  'whim',
#  'vignettes',
#  'leaf',
#  'anatomist',
#  'squatted',
#  'felicities',
#  'renewed',
#  'bandbox',
#  'aromasin',
#  'intensifying',
#  'classic',
#  'juniper',
#  'burnt',
#  'beginner',
#  'summoning',
#  'bask',
#  'tick',
#  'sword',
#  'goods',
#  'cyclades',
#  'throughout',
#  'convulsive',
#  'distantly',
#  'symptoms',
#  'antwerp',
#  'stealthily',
#  'grisly',
#  'consecrated',
#  'raimond',
#  'corpse',
#  'refused',
#  'serpentine',
#  'vomited',
#  'quakerism',
#  'hits',
#  'unsolved',
#  'premeditated',
#  'wane',
#  'coming',
#  'groom',
#  'vicar',
#  '_yours_',
#  'barest',
#  'garnery',
#  'individuality',
#  'grandfather',
#  'hudson',
#  'food',
#  'sod',
#  'jav',
#  '_narwhale_',
#  'consulting',
#  'boots',
#  'labored',
#  'movements',
#  'religion',
#  'unalterable',
#  'skewered',
#  'computer',
#  'phase',
#  'dogger',
#  'respective',
#  'insufferable',
#  'western',
#  '55',
#  'proclamation',
#  'debtor',
#  'dignified',
#  'shout',
#  'holies',
#  'reckoned',
#  'disjointedly',
#  'false',
#  'hostility',
#  'pencil',
#  'doleful',
#  'meetings',
#  'disincline',
#  'overhearing',
#  'stronghold',
#  'narrower',
#  'deputation',
#  'idolatrous',
#  'perish',
#  'tutored',
#  'lye',
#  'sconces',
#  'edging',
#  'heartily',
#  'innocence',
#  'merman',
#  'appallingly',
#  'pastiles',
#  'sweet',
#  'awfulness',
#  'twopence',
#  'unvarying',
#  'saint',
#  'affinities',
#  'architect',
#  'crucible',
#  'sown',
#  'terrors',
#  'rid',
#  'smothering',
#  'fearfulness',
#  'starve',
#  'whereat',
#  'pursuers',
#  'muffledness',
#  'legend',
#  'sworn',
#  'pervading',
#  'allowing',
#  'infirmity',
#  'amazement',
#  'aptiom',
#  'mindedness',
#  'allude',
#  'waistcoat',
#  'nuts',
#  'xr',
#  'hurtling',
#  'lacépède',
#  'exhibition',
#  'arose',
#  'constantly',
#  'except',
#  'occasion',
#  'one_',
#  'glory',
#  'fissure',
#  'hypochondriac',
#  'motley',
#  'approved',
#  'chiefly',
#  'interrupt',
#  'ungodly',
#  'earthy',
#  'difficulty',
#  'authenticated',
#  'huggins',
#  '_thrusts',
#  'unmomentous',
#  'armies',
#  'ghastliness',
#  'obtain',
#  'prediction',
#  'continuous',
#  'simoon',
#  'ostensible',
#  'classical',
#  'represent',
#  'rifles',
#  'walfish',
#  'sight',
#  'earnestness',
#  'predecessors',
#  'longer',
#  'federated',
#  'solicited',
#  'parvo_',
#  ...}

# %%
len(V)
# Out:
# 17789

# %% [markdown]
# # build the frequency of those words

# %%
words_freq_dict = {}
words_freq_dict = Counter(words)

# %%
words_freq_dict.most_common()[0:10]
# Out:
# [('the', 29410),
#  ('of', 13486),
#  ('and', 13038),
#  ('a', 9610),
#  ('to', 9416),
#  ('in', 8476),
#  ('that', 6166),
#  ('it', 5068),
#  ('his', 5060),
#  ('i', 4240)]

# %% [markdown]
# # Relative Frequency of words
# Now we want to get the probability of occurrence of each word, this equals the relative frequencies of the words:

# %% [markdown]
# The formula used to calculate the probability of a word in the provided code is:
#
# Probability(word) = Frequency(word) / Total count of all words

# %%
Total = sum(words_freq_dict.values())
probs = {}

for k in words_freq_dict.keys():
    probs[k] = words_freq_dict[k] / Total

# %%
probs
# Out:
# {'the': 0.06598460882636692,
#  'project': 0.0004083372596531377,
#  'gutenberg': 0.0004217989275537906,
#  'ebook': 4.4872226335509633e-05,
#  'of': 0.03025734221803415,
#  'moby': 0.0004038500370195867,
#  'dick': 0.0004038500370195867,
#  'or': 0.003576316438940118,
#  'whale': 0.0055192838392676856,
#  'by': 0.005483386058199278,
#  'herman': 1.7948890534203855e-05,
#  'melville': 1.7948890534203855e-05,
#  'this': 0.006457113369679837,
#  'is': 0.007857126831347738,
#  'for': 0.007376994009557784,
#  'use': 0.0002198739090439972,
#  'anyone': 2.692333580130578e-05,
#  'anywhere': 7.179556213681542e-05,
#  'at': 0.005994929438424087,
#  'no': 0.0026654102443292725,
#  'cost': 1.7948890534203855e-05,
#  'and': 0.029252204348118732,
#  'with': 0.007946871284018756,
#  'almost': 0.0008839828588095398,
#  'restrictions': 8.974445267101928e-06,
#  'whatsoever': 3.1410558434856746e-05,
#  'you': 0.004298759282941823,
#  'may': 0.0011442417715554958,
#  'copy': 8.525723003746831e-05,
#  'it': 0.011370622153418141,
#  'give': 0.0004038500370195867,
#  'away': 0.0008346234098404792,
#  're': 8.077000740391735e-05,
#  'under': 0.0005653900518274214,
#  'terms': 0.0001480783469071818,
#  'license': 8.077000740391735e-05,
#  'included': 6.282111686971349e-05,
#  'online': 1.7948890534203855e-05,
#  'www': 2.692333580130578e-05,
#  'org': 5.833389423616253e-05,
#  'title': 3.589778106840771e-05,
#  'author': 4.0385003701958675e-05,
#  'release': 4.487222633550964e-06,
#  'date': 1.7948890534203855e-05,
#  'december': 2.2436113167754817e-05,
#  '25': 1.7948890534203855e-05,
#  '2008': 4.487222633550964e-06,
#  '2701': 1.7948890534203855e-05,
#  'last': 0.001247447892127168,
#  'updated': 8.974445267101928e-06,
#  '3': 7.179556213681542e-05,
#  '2017': 4.487222633550964e-06,
#  'language': 3.1410558434856746e-05,
#  'english': 0.0002198739090439972,
#  'character': 6.730833950326445e-05,
#  'set': 0.0003814139238518319,
#  'encoding': 4.487222633550964e-06,
#  'utf': 4.487222633550964e-06,
#  '8': 3.1410558434856746e-05,
#  'start': 0.00017051446007493662,
#  'produced': 4.0385003701958675e-05,
#  'daniel': 1.7948890534203855e-05,
#  'lazarus': 3.1410558434856746e-05,
#  'jonesey': 8.974445267101928e-06,
#  'david': 8.974445267101928e-06,
#  'widger': 8.974445267101928e-06,
#  'contents': 3.589778106840771e-05,
#  'etymology': 8.974445267101928e-06,
#  'extracts': 3.1410558434856746e-05,
#  'supplied': 5.833389423616253e-05,
#  'a': 0.02156110475421238,
#  'sub': 4.0385003701958675e-05,
#  'librarian': 8.974445267101928e-06,
#  'chapter': 0.0013820645711336969,
#  '1': 0.0002198739090439972,
#  'loomings': 8.974445267101928e-06,
#  '2': 3.1410558434856746e-05,
#  'carpet': 4.0385003701958675e-05,
#  'bag': 0.00010320612057167217,
#  'spouter': 3.589778106840771e-05,
#  'inn': 7.628278477036638e-05,
#  '4': 4.0385003701958675e-05,
#  'counterpane': 3.589778106840771e-05,
#  '5': 3.1410558434856746e-05,
#  'breakfast': 6.730833950326445e-05,
#  '6': 1.7948890534203855e-05,
#  'street': 6.282111686971349e-05,
#  '7': 3.1410558434856746e-05,
#  'chapel': 4.93594489690606e-05,
#  'pulpit': 7.628278477036638e-05,
#  '9': 2.692333580130578e-05,
#  'sermon': 2.2436113167754817e-05,
#  '10': 2.2436113167754817e-05,
#  'bosom': 4.0385003701958675e-05,
#  'friend': 0.00012115501110587601,
#  '11': 8.974445267101928e-06,
#  'nightgown': 8.974445267101928e-06,
#  '12': 8.974445267101928e-06,
#  'biographical': 8.974445267101928e-06,
#  '13': 1.7948890534203855e-05,
#  'wheelbarrow': 1.7948890534203855e-05,
#  '14': 8.974445267101928e-06,
#  'nantucket': 0.0004217989275537906,
#  '15': 8.974445267101928e-06,
#  'chowder': 4.4872226335509633e-05,
#  '16': 8.974445267101928e-06,
#  'ship': 0.00232886854681295,
#  '17': 8.974445267101928e-06,
#  'ramadan': 5.384667160261156e-05,
#  '18': 8.974445267101928e-06,
#  'his': 0.011352673262883937,
#  'mark': 0.00025128446747885397,
#  '19': 8.974445267101928e-06,
#  'prophet': 7.628278477036638e-05,
#  '20': 2.2436113167754817e-05,
#  'all': 0.006928271746202688,
#  'astir': 1.7948890534203855e-05,
#  '21': 8.974445267101928e-06,
#  'going': 0.0004038500370195867,
#  'aboard': 9.87188979381212e-05,
#  '22': 8.974445267101928e-06,
#  'merry': 6.282111686971349e-05,
#  'christmas': 2.692333580130578e-05,
#  '23': 8.974445267101928e-06,
#  'lee': 9.423167530457024e-05,
#  'shore': 0.00011666778847232505,
#  '24': 8.974445267101928e-06,
#  'advocate': 1.7948890534203855e-05,
#  'postscript': 8.974445267101928e-06,
#  '26': 8.974445267101928e-06,
#  'knights': 2.692333580130578e-05,
#  'squires': 1.7948890534203855e-05,
#  '27': 8.974445267101928e-06,
#  '28': 8.974445267101928e-06,
#  'ahab': 0.0022974579883780935,
#  '29': 8.974445267101928e-06,
#  'enter': 4.93594489690606e-05,
#  'to': 0.021125844158757935,
#  'him': 0.004778892104731776,
#  'stubb': 0.0011621906620896995,
#  '30': 1.7948890534203855e-05,
#  'pipe': 0.00018846335060914048,
#  '31': 8.974445267101928e-06,
#  'queen': 8.077000740391735e-05,
#  'mab': 8.974445267101928e-06,
#  '32': 8.974445267101928e-06,
#  'cetology': 4.93594489690606e-05,
#  '33': 8.974445267101928e-06,
#  'specksnyder': 1.7948890534203855e-05,
#  '34': 8.974445267101928e-06,
#  'cabin': 0.00039038836911893385,
#  'table': 0.00017051446007493662,
#  '35': 8.974445267101928e-06,
#  'mast': 0.0005833389423616252,
#  'head': 0.0015615534764757354,
#  '36': 8.974445267101928e-06,
#  'quarter': 0.00021538668641044625,
#  'deck': 0.0008929573040766418,
#  '37': 8.974445267101928e-06,
#  'sunset': 4.4872226335509633e-05,
#  '38': 8.974445267101928e-06,
#  'dusk': 1.346166790065289e-05,
#  '39': 8.974445267101928e-06,
#  'first': 0.0010724462094186802,
#  'night': 0.0006820578402997465,
#  'watch': 0.0002737205806466088,
#  '40': 1.346166790065289e-05,
#  'midnight': 0.0001346166790065289,
#  'forecastle': 0.00017051446007493662,
#  '41': 8.974445267101928e-06,
#  '42': 8.974445267101928e-06,
#  'whiteness': 0.00012564223373942698,
#  '43': 8.974445267101928e-06,
#  'hark': 7.628278477036638e-05,
#  '44': 8.974445267101928e-06,
#  'chart': 3.589778106840771e-05,
#  '45': 1.346166790065289e-05,
#  'affidavit': 1.346166790065289e-05,
#  '46': 8.974445267101928e-06,
#  'surmises': 1.7948890534203855e-05,
#  '47': 8.974445267101928e-06,
#  'mat': 5.833389423616253e-05,
#  'maker': 2.2436113167754817e-05,
#  '48': 8.974445267101928e-06,
#  'lowering': 8.525723003746831e-05,
#  '49': 8.974445267101928e-06,
#  'hyena': 1.7948890534203855e-05,
#  '50': 1.346166790065289e-05,
#  's': 0.008162257970429203,
#  'boat': 0.0014987323596060218,
#  'crew': 0.0006326983913306859,
#  'fedallah': 0.00012564223373942698,
#  '51': 8.974445267101928e-06,
#  'spirit': 8.525723003746831e-05,
#  'spout': 0.0002737205806466088,
#  '52': 8.974445267101928e-06,
#  'albatross': 4.4872226335509633e-05,
#  '53': 8.974445267101928e-06,
#  'gam': 2.692333580130578e-05,
#  '54': 8.974445267101928e-06,
#  'town': 0.0001615400148078347,
#  'ho': 0.00014359112427363084,
#  'story': 0.00022884835431109915,
#  '55': 8.974445267101928e-06,
#  'monstrous': 5.384667160261156e-05,
#  'pictures': 8.525723003746831e-05,
#  'whales': 0.001216037333692311,
#  '56': 8.974445267101928e-06,
#  'less': 0.00024231002221175203,
#  'erroneous': 8.974445267101928e-06,
#  'true': 0.0003948755917524848,
#  'whaling': 0.0005923133876287272,
#  'scenes': 5.384667160261156e-05,
#  '57': 8.974445267101928e-06,
#  'in': 0.019016849520988983,
#  'paint': 3.1410558434856746e-05,
#  'teeth': 0.0002243611316775482,
#  'wood': 0.00016602723744138566,
#  'sheet': 4.0385003701958675e-05,
#  'iron': 0.0003948755917524848,
#  'stone': 8.974445267101927e-05,
#  'mountains': 6.282111686971349e-05,
#  'stars': 6.282111686971349e-05,
#  '58': 8.974445267101928e-06,
#  'brit': 4.0385003701958675e-05,
#  '59': 8.974445267101928e-06,
#  'squid': 3.589778106840771e-05,
#  '60': 1.7948890534203855e-05,
#  'line': 0.0007179556213681541,
#  '61': 8.974445267101928e-06,
#  'kills': 1.346166790065289e-05,
#  '62': 8.974445267101928e-06,
#  'dart': 0.00011666778847232505,
#  '63': 8.974445267101928e-06,
#  'crotch': 4.93594489690606e-05,
#  '64': 1.346166790065289e-05,
#  'supper': 0.00013910390164007989,
#  '65': 8.974445267101928e-06,
#  'as': 0.007866101276614839,
#  'dish': 4.93594489690606e-05,
#  '66': 8.974445267101928e-06,
#  'shark': 0.00013910390164007989,
#  'massacre': 1.346166790065289e-05,
#  '67': 8.974445267101928e-06,
#  'cutting': 0.00017051446007493662,
#  '68': 8.974445267101928e-06,
#  'blanket': 6.282111686971349e-05,
#  '69': 8.974445267101928e-06,
#  'funeral': 2.692333580130578e-05,
#  '70': 8.974445267101928e-06,
#  'sphynx': 1.346166790065289e-05,
#  '71': 8.974445267101928e-06,
#  'jeroboam': 4.93594489690606e-05,
#  '72': 1.346166790065289e-05,
#  'monkey': 7.628278477036638e-05,
#  'rope': 0.0002692333580130578,
#  '73': 8.974445267101928e-06,
#  'flask': 0.000489107267057055,
#  'kill': 0.00015256556954073276,
#  'right': 0.0006955195082003993,
#  'then': 0.002826950259137107,
#  'have': 0.003473110318368446,
#  'talk': 0.00011666778847232505,
#  'over': 0.0018397612797558952,
#  '74': 8.974445267101928e-06,
#  'sperm': 0.0010859078773193332,
#  'contrasted': 1.7948890534203855e-05,
#  'view': 0.0002243611316775482,
#  '75': 8.974445267101928e-06,
#  '76': 8.974445267101928e-06,
#  'battering': 3.1410558434856746e-05,
#  'ram': 3.589778106840771e-05,
#  '77': 8.974445267101928e-06,
#  'great': 0.001377577348500146,
#  'heidelburgh': 4.0385003701958675e-05,
#  'tun': 6.730833950326445e-05,
#  '78': 8.974445267101928e-06,
#  'cistern': 2.2436113167754817e-05,
#  'buckets': 2.692333580130578e-05,
#  '79': 8.974445267101928e-06,
#  'prairie': 5.833389423616253e-05,
#  '80': 8.974445267101928e-06,
#  'nut': 2.2436113167754817e-05,
#  '81': 8.974445267101928e-06,
#  'pequod': 0.0007942384061385206,
#  'meets': 6.282111686971349e-05,
#  'virgin': 5.384667160261156e-05,
#  '82': 8.974445267101928e-06,
#  'honor': 0.0001121805658387741,
#  'glory': 8.525723003746831e-05,
#  '83': 8.974445267101928e-06,
#  'jonah': 0.0003814139238518319,
#  'historically': 8.974445267101928e-06,
#  'regarded': 0.0001121805658387741,
#  '84': 8.974445267101928e-06,
#  'pitchpoling': 3.1410558434856746e-05,
#  '85': 8.974445267101928e-06,
#  'fountain': 4.4872226335509633e-05,
#  '86': 8.974445267101928e-06,
#  'tail': 0.00036346503331762805,
#  '87': 8.974445267101928e-06,
#  'grand': 0.00024231002221175203,
#  'armada': 8.974445267101928e-06,
#  '88': 8.974445267101928e-06,
#  'schools': 4.0385003701958675e-05,
#  'schoolmasters': 1.346166790065289e-05,
#  '89': 8.974445267101928e-06,
#  'fast': 0.0002871822485472617,
#  'fish': 0.0007583406250701129,
#  'loose': 0.00016602723744138566,
#  '90': 1.7948890534203855e-05,
#  'heads': 0.00039038836911893385,
#  'tails': 3.589778106840771e-05,
#  '91': 8.974445267101928e-06,
#  'rose': 0.00015705279217428372,
#  'bud': 2.692333580130578e-05,
#  '92': 8.974445267101928e-06,
#  'ambergris': 6.282111686971349e-05,
#  '93': 8.974445267101928e-06,
#  'castaway': 2.2436113167754817e-05,
#  '94': 8.974445267101928e-06,
#  'squeeze': 4.4872226335509633e-05,
#  'hand': 0.0009647528662134572,
#  '95': 8.974445267101928e-06,
#  'cassock': 1.346166790065289e-05,
#  '96': 8.974445267101928e-06,
#  'try': 0.000246797244845303,
#  'works': 0.0002871822485472617,
#  '97': 8.974445267101928e-06,
#  'lamp': 0.0001346166790065289,
#  '98': 8.974445267101928e-06,
#  'stowing': 1.346166790065289e-05,
#  'down': 0.0017006573781158153,
#  'clearing': 2.692333580130578e-05,
#  'up': 0.002360279105247807,
#  '99': 8.974445267101928e-06,
#  'doubloon': 9.423167530457024e-05,
#  '100': 1.7948890534203855e-05,
#  'leg': 0.0004083372596531377,
#  'arm': 0.0004038500370195867,
#  '101': 8.974445267101928e-06,
#  'decanter': 1.346166790065289e-05,
#  '102': 8.974445267101928e-06,
#  'bower': 1.7948890534203855e-05,
#  'arsacides': 1.7948890534203855e-05,
#  '103': 8.974445267101928e-06,
#  'measurement': 1.7948890534203855e-05,
#  'skeleton': 0.00015705279217428372,
#  '104': 8.974445267101928e-06,
#  'fossil': 2.2436113167754817e-05,
#  '105': 8.974445267101928e-06,
#  'does': 0.0004397478180879944,
#  'magnitude': 0.00010320612057167217,
#  'diminish': 2.2436113167754817e-05,
#  'will': 0.0017904018307868346,
#  'he': 0.008507774113212628,
#  'perish': 2.2436113167754817e-05,
#  '106': 8.974445267101928e-06,
#  '107': 8.974445267101928e-06,
#  'carpenter': 0.0002243611316775482,
#  '108': 8.974445267101928e-06,
#  '109': 8.974445267101928e-06,
#  'starbuck': 0.0008929573040766418,
#  '110': 8.974445267101928e-06,
#  'queequeg': 0.0011352673262883938,
#  'coffin': 0.00023782279957820107,
#  '111': 8.974445267101928e-06,
#  'pacific': 0.00015705279217428372,
#  '112': 8.974445267101928e-06,
#  'blacksmith': 9.87188979381212e-05,
#  '113': 8.974445267101928e-06,
#  'forge': 5.833389423616253e-05,
#  '114': 8.974445267101928e-06,
#  'gilder': 8.974445267101928e-06,
#  '115': 8.974445267101928e-06,
#  'bachelor': 4.0385003701958675e-05,
#  '116': 8.974445267101928e-06,
#  'dying': 6.730833950326445e-05,
#  '117': 8.974445267101928e-06,
#  '118': 8.974445267101928e-06,
#  'quadrant': 4.0385003701958675e-05,
#  '119': 8.974445267101928e-06,
#  'candles': 4.4872226335509633e-05,
#  '120': 8.974445267101928e-06,
#  'towards': 0.0005160306028583608,
#  'end': 0.00046218393125574923,
#  '121': 8.974445267101928e-06,
#  'bulwarks': 0.00017051446007493662,
#  '122': 8.974445267101928e-06,
#  'aloft': 0.0002826950259137107,
#  'thunder': 0.00014359112427363084,
#  'lightning': 0.00012564223373942698,
#  '123': 8.974445267101928e-06,
#  'musket': 4.0385003701958675e-05,
#  '124': 8.974445267101928e-06,
#  'needle': 5.384667160261156e-05,
#  '125': 8.974445267101928e-06,
#  'log': 0.00010320612057167217,
#  '126': 8.974445267101928e-06,
#  'life': 0.0007852639608714186,
#  'buoy': 6.282111686971349e-05,
#  '127': 8.974445267101928e-06,
#  '128': 8.974445267101928e-06,
#  'rachel': 3.1410558434856746e-05,
#  '129': 8.974445267101928e-06,
#  '130': 8.974445267101928e-06,
#  'hat': 0.00018397612797558952,
#  '131': 8.974445267101928e-06,
#  'delight': 8.525723003746831e-05,
#  '132': 8.974445267101928e-06,
#  'symphony': 8.974445267101928e-06,
#  '133': 8.974445267101928e-06,
#  'chase': 0.00027820780328015977,
#  'day': 0.0008032128514056225,
#  '134': 8.974445267101928e-06,
#  'second': 0.00027820780328015977,
#  '135': 8.974445267101928e-06,
#  'third': 0.00015256556954073276,
#  'epilogue': 8.974445267101928e-06,
#  'original': 0.00010320612057167217,
#  'transcriber': 4.487222633550964e-06,
#  'notes': 1.7948890534203855e-05,
#  'text': 2.692333580130578e-05,
#  'combination': 8.974445267101928e-06,
#  'etexts': 4.487222633550964e-06,
#  'one': 0.00414619371340109,
#  'from': 0.004953893787440264,
#  'now': 0.0035269569899710573,
#  'defunct': 8.974445267101928e-06,
#  'eris': 4.487222633550964e-06,
#  'virginia': 2.692333580130578e-05,
#  'tech': 8.974445267101928e-06,
#  'archives': 4.487222633550964e-06,
#  'proofreaders': 4.487222633550964e-06,
#  'version': 2.692333580130578e-05,
#  'are': 0.0027731035875344957,
#  'indebted': 8.974445267101928e-06,
#  'university': 4.487222633550964e-06,
#  'adelaide': 4.487222633550964e-06,
#  'library': 1.346166790065289e-05,
#  'preserving': 1.7948890534203855e-05,
#  'resulting': 1.346166790065289e-05,
#  'etext': 4.487222633550964e-06,
#  'was': 0.007385968454824886,
#  'compared': 4.0385003701958675e-05,
#  'public': 6.730833950326445e-05,
#  'domain': 4.0385003701958675e-05,
#  'hard': 0.00037692670121828095,
#  'late': 0.0001346166790065289,
#  'consumptive': 4.487222633550964e-06,
#  'usher': 8.974445267101928e-06,
#  'grammar': 8.974445267101928e-06,
#  'school': 4.4872226335509633e-05,
#  'pale': 8.525723003746831e-05,
#  'threadbare': 4.487222633550964e-06,
#  'coat': 0.00012564223373942698,
#  'heart': 0.0004083372596531377,
#  'body': 0.000493594489690606,
#  'brain': 0.00016602723744138566,
#  'i': 0.009512911983128043,
#  'see': 0.001233986224226515,
#  'ever': 0.0009243678625114985,
#  'dusting': 8.974445267101928e-06,
#  'old': 0.0020282246303650357,
#  'lexicons': 4.487222633550964e-06,
#  'grammars': 8.974445267101928e-06,
#  'queer': 0.0001974377958762424,
#  'handkerchief': 2.2436113167754817e-05,
#  'mockingly': 4.487222633550964e-06,
#  'embellished': 1.346166790065289e-05,
#  'gay': 9.423167530457024e-05,
#  'flags': 4.487222633550964e-06,
#  'known': 0.00035897781068407707,
#  'nations': 5.384667160261156e-05,
#  'world': 0.0007897511835049696,
#  'loved': 1.346166790065289e-05,
#  'dust': 4.4872226335509633e-05,
#  'somehow': 0.0001974377958762424,
#  'mildly': 4.4872226335509633e-05,
#  'reminded': 1.7948890534203855e-05,
#  'mortality': 4.487222633550964e-06,
#  'while': 0.0011038567678535371,
#  'take': 0.000614749500796482,
#  'others': 0.00017948890534203853,
#  'teach': 2.2436113167754817e-05,
#  'them': 0.002126943528303157,
#  'what': 0.0027686163649009447,
#  'name': 0.00031410558434856743,
#  'be': 0.004769917659464674,
#  'called': 0.0005205178254919118,
#  'our': 0.0009468039756792533,
#  'tongue': 4.93594489690606e-05,
#  'leaving': 0.00017051446007493662,
#  'out': 0.0024096385542168677,
#  'through': 0.0010544973188844765,
#  'ignorance': 4.93594489690606e-05,
#  'letter': 8.077000740391735e-05,
#  'h': 1.346166790065289e-05,
#  'which': 0.0029391308249758813,
#  'alone': 0.00018846335060914048,
#  'maketh': 2.2436113167754817e-05,
#  'signification': 4.487222633550964e-06,
#  'word': 0.0003455161427834242,
#  'deliver': 1.346166790065289e-05,
#  'that': 0.01383410737923762,
#  'not': 0.005263512149155281,
#  '_hackluyt': 4.487222633550964e-06,
#  '_': 0.0002198739090439972,
#  'sw': 4.487222633550964e-06,
#  'dan': 3.1410558434856746e-05,
#  '_hval_': 4.487222633550964e-06,
#  'animal': 7.179556213681542e-05,
#  'named': 5.384667160261156e-05,
#  'roundness': 4.487222633550964e-06,
#  'rolling': 0.00015705279217428372,
#  '_hvalt_': 4.487222633550964e-06,
#  'arched': 4.93594489690606e-05,
#  'vaulted': 8.974445267101928e-06,
#  '_webster': 4.487222633550964e-06,
#  'dictionary': 1.7948890534203855e-05,
#  'more': 0.0022750218752103386,
#  'immediately': 7.628278477036638e-05,
#  'dut': 4.487222633550964e-06,
#  'ger': 4.487222633550964e-06,
#  '_wallen_': 4.487222633550964e-06,
#  '_walw': 4.487222633550964e-06,
#  'ian_': 4.487222633550964e-06,
#  'roll': 8.077000740391735e-05,
#  'wallow': 1.346166790065289e-05,
#  '_richardson': 4.487222633550964e-06,
#  'חו': 4.487222633550964e-06,
#  '_hebrew_': 4.487222633550964e-06,
#  'ϰητος': 4.487222633550964e-06,
#  '_greek_': 4.487222633550964e-06,
#  'cetus': 1.346166790065289e-05,
#  '_latin_': 4.487222633550964e-06,
#  'whœl': 4.487222633550964e-06,
#  '_anglo': 4.487222633550964e-06,
#  'saxon_': 4.487222633550964e-06,
#  'hvalt': 4.487222633550964e-06,
#  '_danish_': 4.487222633550964e-06,
#  'wal': 4.487222633550964e-06,
#  '_dutch_': 4.487222633550964e-06,
#  'hwal': 4.487222633550964e-06,
#  '_swedish_': 4.487222633550964e-06,
#  '_icelandic_': 4.487222633550964e-06,
#  '_english_': 4.487222633550964e-06,
#  'ballena': 4.487222633550964e-06,
#  '_spanish_': 4.487222633550964e-06,
#  'pekee': 4.487222633550964e-06,
#  'nuee': 1.7948890534203855e-05,
#  '_fegee_': 4.487222633550964e-06,
#  'pehee': 4.487222633550964e-06,
#  '_erromangoan_': 4.487222633550964e-06,
#  'seen': 0.000740391734535909,
#  'mere': 0.00018846335060914048,
#  'painstaking': 4.487222633550964e-06,
#  'burrower': 4.487222633550964e-06,
#  'grub': 8.974445267101928e-06,
#  'worm': 2.2436113167754817e-05,
#  'poor': 0.0005115433802248099,
#  'devil': 0.000246797244845303,
#  'appears': 3.589778106840771e-05,
#  'gone': 0.00026474613537950687,
#  'long': 0.0014897579143389199,
#  'vaticans': 4.487222633550964e-06,
#  'stalls': 4.487222633550964e-06,
#  'earth': 0.00020641224114334434,
#  'picking': 1.7948890534203855e-05,
#  'whatever': 0.00020641224114334434,
#  'random': 2.2436113167754817e-05,
#  'allusions': 3.1410558434856746e-05,
#  'could': 0.0009737273114805591,
#  'anyways': 8.974445267101928e-06,
#  'find': 0.00025128446747885397,
#  'any': 0.0016333490386125507,
#  'book': 0.0002692333580130578,
#  'sacred': 4.4872226335509633e-05,
#  'profane': 2.2436113167754817e-05,
#  'therefore': 0.0003006439164479146,
#  'must': 0.0013147562316304323,
#  'every': 0.0010410356509838235,
#  'case': 0.0003230800296156694,
#  'least': 0.00034102892014987324,
#  'higgledy': 4.487222633550964e-06,
#  'piggledy': 4.487222633550964e-06,
#  'statements': 2.2436113167754817e-05,
#  'however': 0.0004307733728208925,
#  'authentic': 1.346166790065289e-05,
#  'these': 0.0018173251665881403,
#  'veritable': 1.7948890534203855e-05,
#  'gospel': 8.974445267101928e-06,
#  'far': 0.000740391734535909,
#  'touching': 0.00020641224114334434,
#  'ancient': 0.00012564223373942698,
#  'authors': 1.7948890534203855e-05,
#  'generally': 0.00013910390164007989,
#  'well': 0.0010320612057167216,
#  'poets': 1.346166790065289e-05,
#  'here': 0.0014359112427363083,
#  'appearing': 1.7948890534203855e-05,
#  'solely': 2.692333580130578e-05,
#  'valuable': 4.93594489690606e-05,
#  'entertaining': 8.974445267101928e-06,
#  'affording': 8.974445267101928e-06,
#  'glancing': 6.282111686971349e-05,
#  'bird': 7.628278477036638e-05,
#  'eye': 0.0003948755917524848,
#  'has': 0.0013147562316304323,
#  'been': 0.00186219739292365,
#  'promiscuously': 4.487222633550964e-06,
#  'said': 0.001368602903233044,
#  'thought': 0.0006730833950326445,
#  'fancied': 4.0385003701958675e-05,
#  'sung': 8.974445267101928e-06,
#  'leviathan': 0.00042628615018734157,
#  'many': 0.0007538534024365619,
#  'generations': 3.589778106840771e-05,
#  'including': 7.179556213681542e-05,
#  'own': 0.0009198806398779476,
#  'so': 0.0047833793273653275,
#  'fare': 4.4872226335509633e-05,
#  'thee': 0.0005878261649951762,
#  'whose': 0.00039038836911893385,
#  'commentator': 4.487222633550964e-06,
#  'am': 0.0004083372596531377,
#  'thou': 0.001216037333692311,
#  'belongest': 4.487222633550964e-06,
#  'hopeless': 3.589778106840771e-05,
#  'sallow': 4.487222633550964e-06,
#  'tribe': 4.0385003701958675e-05,
#  'wine': 5.384667160261156e-05,
#  'warm': 0.00010769334320522313,
#  'whom': 0.00020192501850979335,
#  'even': 0.000866033968275336,
#  'sherry': 4.487222633550964e-06,
#  'would': 0.0019384801776940162,
#  'too': 0.0008301361872069282,
#  'rosy': 8.974445267101928e-06,
#  'strong': 0.0001615400148078347,
#  'but': 0.008180206860963407,
#  'sometimes': 0.00039038836911893385,
#  'loves': 4.487222633550964e-06,
#  'sit': 6.730833950326445e-05,
#  'feel': 0.00025577169011240495,
#  'devilish': 4.0385003701958675e-05,
#  'grow': 0.00010769334320522313,
#  'convivial': 1.7948890534203855e-05,
#  'upon': 0.0025487424558569474,
#  'tears': 2.692333580130578e-05,
#  'say': 0.0010948823225864351,
#  'bluntly': 4.487222633550964e-06,
#  'full': 0.000610262278162931,
#  'eyes': 0.0007000067308339503,
#  'empty': 9.87188979381212e-05,
#  'glasses': 4.4872226335509633e-05,
#  'altogether': 0.00013012945637297794,
#  'unpleasant': 1.346166790065289e-05,
#  'sadness': 8.974445267101928e-06,
#  'subs': 4.487222633550964e-06,
#  'how': 0.0011577034394561487,
#  'much': 0.0010051378699154159,
#  'pains': 6.730833950326445e-05,
#  'ye': 0.002117969083036055,
#  'please': 7.179556213681542e-05,
#  'shall': 0.0004352605954544435,
#  'go': 0.000866033968275336,
#  'thankless': 4.487222633550964e-06,
#  'clear': 0.00018397612797558952,
#  'hampton': 4.487222633550964e-06,
#  'court': 8.974445267101928e-06,
#  'tuileries': 1.346166790065289e-05,
#  'gulp': 8.974445267101928e-06,
#  'your': 0.0011532162168225977,
#  'hie': 4.487222633550964e-06,
#  'royal': 0.00012564223373942698,
#  'hearts': 0.00013012945637297794,
#  'friends': 7.628278477036638e-05,
#  'who': 0.0016423234838796527,
#  'before': 0.00135065401269884,
#  'seven': 7.179556213681542e-05,
#  'storied': 1.7948890534203855e-05,
#  'heavens': 7.628278477036638e-05,
#  'making': 0.00020641224114334434,
#  'refugees': 4.487222633550964e-06,
#  'pampered': 4.487222633550964e-06,
#  'gabriel': 8.974445267101927e-05,
#  'michael': 1.346166790065289e-05,
#  'raphael': 4.487222633550964e-06,
#  'against': 0.00060577505552938,
#  'coming': 0.00024231002221175203,
#  'strike': 0.00014359112427363084,
#  'splintered': 3.1410558434856746e-05,
#  'together': 0.0002871822485472617,
#  'there': 0.0038814475780215834,
#  'unsplinterable': 4.487222633550964e-06,
#  'god': 0.0006865450629332975,
#  'created': 4.0385003701958675e-05,
#  '_genesis_': 4.487222633550964e-06,
#  'path': 4.4872226335509633e-05,
#  'shine': 1.346166790065289e-05,
#  'after': 0.00121155011105876,
#  'think': 0.0005474411612932176,
#  'deep': 0.00031410558434856743,
#  'hoary': 8.974445267101928e-06,
#  '_job_': 4.487222633550964e-06,
#  'lord': 0.0002916694711808126,
#  'had': 0.003495546431536201,
#  'prepared': 5.384667160261156e-05,
#  'swallow': 4.93594489690606e-05,
#  '_jonah_': 4.487222633550964e-06,
#  'ships': 0.0003948755917524848,
#  'hast': 0.00013012945637297794,
#  'made': 0.0007987256287720715,
#  'play': 0.00013012945637297794,
#  'therein': 2.692333580130578e-05,
#  '_psalms_': 4.487222633550964e-06,
#  'sore': 1.346166790065289e-05,
#  'sword': 0.0001121805658387741,
#  'punish': 4.487222633550964e-06,
#  'piercing': 1.7948890534203855e-05,
#  'serpent': 1.7948890534203855e-05,
#  'crooked': 3.589778106840771e-05,
#  'slay': 1.7948890534203855e-05,
#  'dragon': 2.692333580130578e-05,
#  'sea': 0.0020416862982656886,
#  '_isaiah_': 4.487222633550964e-06,
#  'thing': 0.0008435978551075812,
#  'soever': 4.487222633550964e-06,
#  'besides': 0.0002243611316775482,
#  'cometh': 4.487222633550964e-06,
#  'within': 0.00037243947858472997,
#  'chaos': 1.7948890534203855e-05,
#  'monster': 0.0002198739090439972,
#  'mouth': 0.0002737205806466088,
#  'beast': 1.7948890534203855e-05,
#  'goes': 0.000246797244845303,
#  'incontinently': 4.487222633550964e-06,
#  'foul': 4.93594489690606e-05,
#  'perisheth': 4.487222633550964e-06,
#  'bottomless': 3.1410558434856746e-05,
#  'gulf': 2.692333580130578e-05,
#  'paunch': 8.974445267101928e-06,
#  '_holland': 8.974445267101928e-06,
#  'plutarch': 4.487222633550964e-06,
#  'morals_': 4.487222633550964e-06,
#  'indian': 0.00025577169011240495,
#  'breedeth': 4.487222633550964e-06,
#  'most': 0.0012833456731955756,
#  'biggest': 8.974445267101928e-06,
#  'fishes': 2.2436113167754817e-05,
#  'among': 0.0007493661798030109,
#  'whirlpooles': 4.487222633550964e-06,
#  'balaene': 4.487222633550964e-06,
#  'length': 0.00035000336541697515,
#  'four': 0.0003320544748827713,
#  'acres': 1.346166790065289e-05,
#  'arpens': 4.487222633550964e-06,
#  'land': 0.00035897781068407707,
#  'pliny_': 4.487222633550964e-06,
#  'scarcely': 4.0385003701958675e-05,
#  'we': 0.002104507415135402,
#  'proceeded': 2.692333580130578e-05,
#  'two': 0.0013282178995310853,
#  'days': 0.00038590114648538287,
#  'on': 0.004814789885800184,
#  'when': 0.002723744138565435,
#  'about': 0.0014269367974692065,
#  'sunrise': 4.93594489690606e-05,
#  'other': 0.0019295057324269145,
#  'monsters': 4.0385003701958675e-05,
#  'appeared': 4.4872226335509633e-05,
#  'former': 8.974445267101927e-05,
#  'size': 5.384667160261156e-05,
#  'came': 0.0005833389423616252,
#  'us': 0.0010275739830831706,
#  'open': 0.00034102892014987324,
#  'mouthed': 2.2436113167754817e-05,
#  'raising': 2.2436113167754817e-05,
#  'waves': 0.00021538668641044625,
#  'sides': 0.00012564223373942698,
#  'beating': 4.93594489690606e-05,
#  'into': 0.002346817437347154,
#  'foam': 8.525723003746831e-05,
#  '_tooke': 4.487222633550964e-06,
#  'lucian_': 4.487222633550964e-06,
#  '_the': 5.384667160261156e-05,
#  'history_': 4.487222633550964e-06,
#  'visited': 3.1410558434856746e-05,
#  'country': 0.00012115501110587601,
#  'also': 0.0004173117049202396,
#  'catching': 3.1410558434856746e-05,
#  'horse': 0.00012115501110587601,
#  'bones': 0.0002198739090439972,
#  'very': 0.0014493729106369612,
#  'value': 2.692333580130578e-05,
#  'their': 0.0027820780328015973,
#  'brought': 0.00017051446007493662,
#  'some': 0.0027775908101680463,
#  'king': 0.0002826950259137107,
#  'best': 0.0002961566938143636,
#  'were': 0.003064773058715308,
#  'catched': 4.487222633550964e-06,
#  'forty': 0.0001480783469071818,
#  'eight': 0.00012115501110587601,
#  'fifty': 0.0001480783469071818,
#  'yards': 0.00012115501110587601,
#  'six': 0.00013910390164007989,
#  'killed': 0.00015705279217428372,
#  'sixty': 7.628278477036638e-05,
#  '_other': 4.487222633550964e-06,
#  'verbal': 8.974445267101928e-06,
#  'narrative': 4.0385003701958675e-05,
#  'taken': 0.00022884835431109915,
#  'alfred': 8.974445267101928e-06,
#  'd': 0.00033654169751632225,
#  '890': 4.487222633550964e-06,
#  'whereas': 8.077000740391735e-05,
#  'things': 0.0006012878328958292,
#  'whether': 0.0004083372596531377,
#  'vessel': 0.000246797244845303,
#  'dreadful': 2.692333580130578e-05,
#  'lost': 0.0002108994637768953,
#  'swallowed': 5.833389423616253e-05,
#  'gudgeon': 4.487222633550964e-06,
#  'retires': 4.487222633550964e-06,
#  'security': 1.346166790065289e-05,
#  'sleeps': 3.1410558434856746e-05,
#  'montaigne': 4.487222633550964e-06,
#  '_apology': 4.487222633550964e-06,
#  'raimond': 4.487222633550964e-06,
#  'sebond_': 4.487222633550964e-06,
#  'let': 0.0007089811761010523,
#  'fly': 6.282111686971349e-05,
#  'nick': 8.974445267101928e-06,
#  'me': 0.002822463036503556,
#  'if': 0.0022480985394090327,
#  'described': 4.0385003701958675e-05,
#  'noble': 0.0001974377958762424,
#  'moses': 8.974445267101928e-06,
#  'patient': 3.589778106840771e-05,
#  'job': 6.282111686971349e-05,
#  '_rabelais_': 4.487222633550964e-06,
#  'liver': 1.7948890534203855e-05,
#  'cartloads': 4.487222633550964e-06,
#  '_stowe': 4.487222633550964e-06,
#  'annals_': 4.487222633550964e-06,
#  'seas': 0.00039038836911893385,
#  'seethe': 1.346166790065289e-05,
#  'like': 0.0029032330439074734,
#  'boiling': 6.730833950326445e-05,
#  'pan': 2.2436113167754817e-05,
#  '_lord': 4.487222633550964e-06,
#  'bacon': 4.487222633550964e-06,
#  'psalms_': 4.487222633550964e-06,
#  'bulk': 0.00014359112427363084,
#  'ork': 4.487222633550964e-06,
#  'received': 0.00013910390164007989,
#  'nothing': 0.0005160306028583608,
#  'certain': 0.0004083372596531377,
#  'they': 0.0029974647192120437,
#  'exceeding': 5.384667160261156e-05,
#  'fat': 6.282111686971349e-05,
#  'insomuch': 8.974445267101928e-06,
#  'an': 0.002696820802764129,
#  'incredible': 4.0385003701958675e-05,
#  'quantity': 5.833389423616253e-05,
#  'oil': 0.0004038500370195867,
#  'extracted': 2.2436113167754817e-05,
#  '_ibid_': 1.346166790065289e-05,
#  '_history': 4.487222633550964e-06,
#  'death_': 4.487222633550964e-06,
#  'sovereignest': 4.487222633550964e-06,
#  'parmacetti': 1.346166790065289e-05,
#  'inward': 2.2436113167754817e-05,
#  'bruise': 4.487222633550964e-06,
#  '_king': 4.487222633550964e-06,
#  'henry_': 4.487222633550964e-06,
#  '_hamlet_': 4.487222633550964e-06,
#  'secure': 5.833389423616253e-05,
#  'skill': 4.4872226335509633e-05,
#  'leach': 4.487222633550964e-06,
#  'art': 0.00018397612797558952,
#  'mote': 4.487222633550964e-06,
#  'availle': 4.487222633550964e-06,
#  'returne': 4.487222633550964e-06,
#  'againe': 4.487222633550964e-06,
#  'wound': 7.628278477036638e-05,
#  'worker': 4.487222633550964e-06,
#  'lowly': 3.589778106840771e-05,
#  'dinting': 4.487222633550964e-06,
#  'breast': 3.1410558434856746e-05,
#  'bred': 4.0385003701958675e-05,
#  'restless': 1.7948890534203855e-05,
#  'paine': 4.487222633550964e-06,
#  'wounded': 4.0385003701958675e-05,
#  'flies': 3.1410558434856746e-05,
#  'thro': 4.487222633550964e-06,
#  'maine': 4.487222633550964e-06,
#  'faerie': 4.487222633550964e-06,
#  'queen_': 4.487222633550964e-06,
#  'immense': 7.179556213681542e-05,
#  'motion': 7.628278477036638e-05,
#  'vast': 0.00032756725224922033,
#  'bodies': 4.0385003701958675e-05,
#  'can': 0.001108343990487088,
#  'peaceful': 2.692333580130578e-05,
#  'calm': 0.00018397612797558952,
#  'trouble': 4.93594489690606e-05,
#  'ocean': 0.00035449058805052614,
#  'till': 0.0005519283839267686,
#  'boil': 8.974445267101928e-06,
#  '_sir': 1.7948890534203855e-05,
#  'william': 1.7948890534203855e-05,
#  'davenant': 4.487222633550964e-06,
#  'preface': 4.487222633550964e-06,
#  'gondibert_': 4.487222633550964e-06,
#  'spermacetti': 1.346166790065289e-05,
#  'men': 0.0010948823225864351,
#  'might': 0.0008211617419398264,
#  'justly': 1.346166790065289e-05,
#  'doubt': 0.00014359112427363084,
#  'since': 0.0002916694711808126,
#  'learned': 0.0001121805658387741,
#  'hosmannus': 4.487222633550964e-06,
#  'work': 0.000489107267057055,
#  'thirty': 0.00012564223373942698,
#  'years': 0.0004352605954544435,
#  'saith': 2.2436113167754817e-05,
#  'plainly': 0.00017500168270848758,
#  '_nescio': 4.487222633550964e-06,
#  'quid': 8.974445267101928e-06,
#  'sit_': 4.487222633550964e-06,
#  't': 0.0013012945637297794,
#  'browne': 2.692333580130578e-05,
#  'sperma': 1.346166790065289e-05,
#  'ceti': 1.346166790065289e-05,
#  'vide': 4.487222633550964e-06,
#  'v': 3.1410558434856746e-05,
#  'e': 0.0002333355769446501,
#  'spencer': 4.487222633550964e-06,
#  'talus': 4.487222633550964e-06,
#  'modern': 8.077000740391735e-05,
#  'flail': 4.487222633550964e-06,
#  'threatens': 4.487222633550964e-06,
#  'ruin': 2.2436113167754817e-05,
#  'ponderous': 5.833389423616253e-05,
#  'fixed': 0.00017051446007493662,
#  'jav': 4.487222633550964e-06,
#  'lins': 4.487222633550964e-06,
#  'side': 0.0009333423077786004,
#  'wears': 3.1410558434856746e-05,
#  'back': 0.0007224428440017051,
#  'grove': 1.346166790065289e-05,
#  'pikes': 8.974445267101928e-06,
#  '_waller': 4.487222633550964e-06,
#  'battle': 0.00013910390164007989,
#  'summer': 7.179556213681542e-05,
#  'islands_': 4.487222633550964e-06,
#  'commonwealth': 4.487222633550964e-06,
#  'state': 0.0001480783469071818,
#  'latin': 1.7948890534203855e-05,
#  'civitas': 4.487222633550964e-06,
#  'artificial': 2.2436113167754817e-05,
#  'man': 0.002364766327881358,
#  '_opening': 4.487222633550964e-06,
#  'sentence': 1.346166790065289e-05,
#  'hobbes': 4.487222633550964e-06,
#  'leviathan_': 4.487222633550964e-06,
#  'silly': 2.2436113167754817e-05,
#  'mansoul': 4.487222633550964e-06,
#  'without': 0.0007359045119023581,
#  'chewing': 4.487222633550964e-06,
#  'sprat': 4.487222633550964e-06,
#  '_pilgrim': 4.487222633550964e-06,
#  'progress_': 4.487222633550964e-06,
#  'hugest': 1.7948890534203855e-05,
#  'swim': 9.423167530457024e-05,
#  'stream': 4.93594489690606e-05,
#  '_paradise': 4.487222633550964e-06,
#  'lost_': 4.487222633550964e-06,
#  'living': 0.00032756725224922033,
#  'creatures': 0.00015256556954073276,
#  'stretched': 4.4872226335509633e-05,
#  'promontory': 2.2436113167754817e-05,
#  'swims': 3.589778106840771e-05,
#  'seems': 0.00039038836911893385,
#  'moving': 6.730833950326445e-05,
#  'gills': 1.7948890534203855e-05,
#  'draws': 4.487222633550964e-06,
#  'breath': 8.077000740391735e-05,
#  'spouts': 7.179556213681542e-05,
#  'mighty': 0.0002108994637768953,
#  'water': 0.0008525723003746831,
#  'swimming': 0.0001346166790065289,
#  '_fuller': 4.487222633550964e-06,
#  'holy': 9.423167530457024e-05,
#  'state_': 4.487222633550964e-06,
#  'close': 0.00025128446747885397,
#  'behind': 0.0002243611316775482,
#  ...}

# %% [markdown]
# # Finding Similar Words
# Now we will sort similar words according to the Jaccard distance by calculating the 2 grams Q of the words. Next, we will return the 5 most similar words ordered by similarity and probability:
#
#
# The Jaccard distance measures the dissimilarity between two sets by comparing their intersection and union

# %%
def autocorrect(word):
    word = word.lower()
    if word in V:
        return('Your word seems to be correct', word)
    else:
        similarities = [1-(textdistance.Jaccard(qval=2).distance(v,word))  for v in words_freq_dict.keys()]
        df = pd.DataFrame.from_dict(probs, orient='index').reset_index()
        df = df.rename(columns={'index':'Word',0:'Prob'})
        df['Similarity'] = similarities
        output = df.sort_values(['Similarity','Prob'],ascending=False).head(3)
        return(output)
autocorrect("parace")
# Out:
#              Word      Prob  Similarity
# 4792         race  0.000076    0.600000
# 7996         pace  0.000031    0.600000
# 15073  paracelsus  0.000004    0.555556
